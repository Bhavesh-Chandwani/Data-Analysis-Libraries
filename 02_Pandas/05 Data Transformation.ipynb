# %% [markdown]
# Once your data is clean, the next step is to reshape, reformat, and reorder it as
# needed for analysis. Pandas gives you plenty of flexible tools to do this.

# %% [markdown]
# **Data Loading**

# %%
import pandas as pd

# %%
df = pd.read_csv("B'Wood Movies Data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %% [markdown]
# **1. Sorting**- Manipulating the sequence of the columns according to needs

# %% [markdown]
# **i. Sort by Values.**

# %%
# Sorting in Ascending Order
df.sort_values('Year')
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 2                   2024   8.4
# 1                    565   6.0
# 10                   201   6.1
# 5                    111   8.3
# 6                    180   7.5
# 4                    585   7.0
# 8                    318   7.0
# 7                    475   6.5
# 11                   342   8.2
# 3                    431   5.6
# 9                    266   5.9
# 0                   1050   7.2

# %%
# Sorting in Descending Order
df.sort_values("Year", ascending=False)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 9                    266   5.9
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 6                    180   7.5
# 5                    111   8.3
# 4                    585   7.0
# 1                    565   6.0
# 10                   201   6.1
# 2                   2024   8.4

# %%
#Sorting By Columns. When the one columns gets ties with value. The sorting will continue
#Using other Column. Suppose in our dataset if the "Year" column gets ties then it will sort it using 
#IMDB Column. The lowest IMDb will get the priority
df.sort_values(["Year", "IMDb"])
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 2                   2024   8.4
# 1                    565   6.0
# 10                   201   6.1
# 4                    585   7.0
# 6                    180   7.5
# 5                    111   8.3
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 3                    431   5.6
# 9                    266   5.9
# 0                   1050   7.2

# %% [markdown]
# **Lets create the new DataFrame from this to perform sorting operation on index.**

# %%
#Creating the copy because panda somtime returns the view(change in origial data) df2
df2 = df.sort_values(["Year", "IMDb"]).copy() 
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 2                   2024   8.4
# 1                    565   6.0
# 10                   201   6.1
# 4                    585   7.0
# 6                    180   7.5
# 5                    111   8.3
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 3                    431   5.6
# 9                    266   5.9
# 0                   1050   7.2

# %%
#Resetting the index of our new data frame df2
df2.reset_index()
# Out:
#     index               Actor                      Film  Year  \
# 0       2          Aamir Khan                    Dangal  2016
# 1       1         Salman Khan           Tiger Zinda Hai  2017
# 2      10        Varun Dhawan     Badrinath Ki Dulhania  2017
# 3       4       Ranveer Singh                 Padmaavat  2018
# 4       6       Rajkummar Rao                     Stree  2018
# 5       5  Ayushmann Khurrana                 Andhadhun  2018
# 6       7      Hrithik Roshan                       War  2019
# 7       8        Akshay Kumar                Good Newwz  2019
# 8      11       Vicky Kaushal  Uri: The Surgical Strike  2019
# 9       3       Ranbir Kapoor                Brahmastra  2022
# 10      9       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 11      0      Shah Rukh Khan                   Pathaan  2023
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0         Biography                  2024   8.4
# 1            Action                   565   6.0
# 2   Romantic Comedy                   201   6.1
# 3        Historical                   585   7.0
# 4     Horror Comedy                   180   7.5
# 5          Thriller                   111   8.3
# 6            Action                   475   6.5
# 7            Comedy                   318   7.0
# 8            Action                   342   8.2
# 9           Fantasy                   431   5.6
# 10    Horror Comedy                   266   5.9
# 11           Action                  1050   7.2

# %%
# Reset Index does not change the origial index of the data frame
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 2                   2024   8.4
# 1                    565   6.0
# 10                   201   6.1
# 4                    585   7.0
# 6                    180   7.5
# 5                    111   8.3
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 3                    431   5.6
# 9                    266   5.9
# 0                   1050   7.2

# %%
# As we used the reset_index() Function on our df2 it surely reset the index of our df2
# but it also created the separate index column to store the indexes of the original df we can drop it
#This method will drop the index column. This will not change the change the original df2
df2.reset_index(drop=True)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   2024   8.4
# 1                    565   6.0
# 2                    201   6.1
# 3                    585   7.0
# 4                    180   7.5
# 5                    111   8.3
# 6                    475   6.5
# 7                    318   7.0
# 8                    342   8.2
# 9                    431   5.6
# 10                   266   5.9
# 11                  1050   7.2

# %%
# The original df2 is still Unchanged.
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 2                   2024   8.4
# 1                    565   6.0
# 10                   201   6.1
# 4                    585   7.0
# 6                    180   7.5
# 5                    111   8.3
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 3                    431   5.6
# 9                    266   5.9
# 0                   1050   7.2

# %%
# We can change the index of the df2 permanently by using 'inplace' method.
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   2024   8.4
# 1                    565   6.0
# 2                    201   6.1
# 3                    585   7.0
# 4                    180   7.5
# 5                    111   8.3
# 6                    475   6.5
# 7                    318   7.0
# 8                    342   8.2
# 9                    431   5.6
# 10                   266   5.9
# 11                  1050   7.2

# %% [markdown]
# **ii. Sort By Index**- The df.sort_index() function is used to sort the DataFrame based on its index
# values. If the index is not in a sequential order (e.g., you have dropped rows or
# performed other operations that change the index), you can use sort_index() to
# restore it to a sorted order.

# %%
# Lets perform sorting through index.
df2.sort_values("IMDb")
# Out:
#                  Actor                      Film  Year            Genre  \
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 6       Hrithik Roshan                       War  2019           Action
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 0           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# 9                    431   5.6
# 10                   266   5.9
# 1                    565   6.0
# 2                    201   6.1
# 6                    475   6.5
# 3                    585   7.0
# 7                    318   7.0
# 11                  1050   7.2
# 4                    180   7.5
# 8                    342   8.2
# 5                    111   8.3
# 0                   2024   8.4

# %%
df2.sort_index()
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   2024   8.4
# 1                    565   6.0
# 2                    201   6.1
# 3                    585   7.0
# 4                    180   7.5
# 5                    111   8.3
# 6                    475   6.5
# 7                    318   7.0
# 8                    342   8.2
# 9                    431   5.6
# 10                   266   5.9
# 11                  1050   7.2

# %% [markdown]
# **2. Ranking**- It is used to assign ranks to a numeric value in a column, like scores or point.
# By default it give average rank to the tied values which can result in decimal number.

# %%
df2["Rank"] = df2["IMDb"].rank()
df2
# Here we can see that the higher the 'IMDb' greater the rank.
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb  Rank
# 0                   2024   8.4  12.0
# 1                    565   6.0   3.0
# 2                    201   6.1   4.0
# 3                    585   7.0   6.5
# 4                    180   7.5   9.0
# 5                    111   8.3  11.0
# 6                    475   6.5   5.0
# 7                    318   7.0   6.5
# 8                    342   8.2  10.0
# 9                    431   5.6   1.0
# 10                   266   5.9   2.0
# 11                  1050   7.2   8.0

# %%
# To give the rank 1 to the Highesh "IMDb" we can do
df2["Rank"] = df2["IMDb"].rank(ascending=False)
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb  Rank
# 0                   2024   8.4   1.0
# 1                    565   6.0  10.0
# 2                    201   6.1   9.0
# 3                    585   7.0   6.5
# 4                    180   7.5   4.0
# 5                    111   8.3   2.0
# 6                    475   6.5   8.0
# 7                    318   7.0   6.5
# 8                    342   8.2   3.0
# 9                    431   5.6  12.0
# 10                   266   5.9  11.0
# 11                  1050   7.2   5.0

# %%
# As we can see in the above data the ties 'IMDb" getting the decimal rank to give the rank
#in integer we will use dense method.
df2["Rank"] = df2["IMDb"].rank(ascending=False, method="dense")
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb  Rank
# 0                   2024   8.4   1.0
# 1                    565   6.0   9.0
# 2                    201   6.1   8.0
# 3                    585   7.0   6.0
# 4                    180   7.5   4.0
# 5                    111   8.3   2.0
# 6                    475   6.5   7.0
# 7                    318   7.0   6.0
# 8                    342   8.2   3.0
# 9                    431   5.6  11.0
# 10                   266   5.9  10.0
# 11                  1050   7.2   5.0

# %% [markdown]
# **3. Renaming Columns and Indexes**

# %%
df2.rename(columns={"IMDb" : "IMDb Rating"})   # we can do inplace=True to make changes in original data.
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb Rating  Rank
# 0                   2024          8.4   1.0
# 1                    565          6.0   9.0
# 2                    201          6.1   8.0
# 3                    585          7.0   6.0
# 4                    180          7.5   4.0
# 5                    111          8.3   2.0
# 6                    475          6.5   7.0
# 7                    318          7.0   6.0
# 8                    342          8.2   3.0
# 9                    431          5.6  11.0
# 10                   266          5.9  10.0
# 11                  1050          7.2   5.0

# %%
df2.rename(index={0 : "row 1", 1 : "row 2", 2 : "row 3", 3 : "row 4"}) # so on,  we can do inplace=True to make changes in original data.
# Out:
#                     Actor                      Film  Year            Genre  \
# row 1          Aamir Khan                    Dangal  2016        Biography
# row 2         Salman Khan           Tiger Zinda Hai  2017           Action
# row 3        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# row 4       Ranveer Singh                 Padmaavat  2018       Historical
# 4           Rajkummar Rao                     Stree  2018    Horror Comedy
# 5      Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6          Hrithik Roshan                       War  2019           Action
# 7            Akshay Kumar                Good Newwz  2019           Comedy
# 8           Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9           Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10          Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11         Shah Rukh Khan                   Pathaan  2023           Action
#
#        BoxOffice(INR Crore)  IMDb  Rank
# row 1                  2024   8.4   1.0
# row 2                   565   6.0   9.0
# row 3                   201   6.1   8.0
# row 4                   585   7.0   6.0
# 4                       180   7.5   4.0
# 5                       111   8.3   2.0
# 6                       475   6.5   7.0
# 7                       318   7.0   6.0
# 8                       342   8.2   3.0
# 9                       431   5.6  11.0
# 10                      266   5.9  10.0
# 11                     1050   7.2   5.0

# %%
df2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb  Rank
# 0                   2024   8.4   1.0
# 1                    565   6.0   9.0
# 2                    201   6.1   8.0
# 3                    585   7.0   6.0
# 4                    180   7.5   4.0
# 5                    111   8.3   2.0
# 6                    475   6.5   7.0
# 7                    318   7.0   6.0
# 8                    342   8.2   3.0
# 9                    431   5.6  11.0
# 10                   266   5.9  10.0
# 11                  1050   7.2   5.0

# %% [markdown]
# **4. Changing Column Order**

# %%
df2 = df2[["Film", "Actor", "Genre", "Year", "IMDb", "Rank", "BoxOffice(INR Crore)"]]
df2
# Out:
#                         Film               Actor            Genre  Year  IMDb  \
# 0                     Dangal          Aamir Khan        Biography  2016   8.4
# 1            Tiger Zinda Hai         Salman Khan           Action  2017   6.0
# 2      Badrinath Ki Dulhania        Varun Dhawan  Romantic Comedy  2017   6.1
# 3                  Padmaavat       Ranveer Singh       Historical  2018   7.0
# 4                      Stree       Rajkummar Rao    Horror Comedy  2018   7.5
# 5                  Andhadhun  Ayushmann Khurrana         Thriller  2018   8.3
# 6                        War      Hrithik Roshan           Action  2019   6.5
# 7                 Good Newwz        Akshay Kumar           Comedy  2019   7.0
# 8   Uri: The Surgical Strike       Vicky Kaushal           Action  2019   8.2
# 9                 Brahmastra       Ranbir Kapoor          Fantasy  2022   5.6
# 10         Bhool Bhulaiyaa 2       Kartik Aaryan    Horror Comedy  2022   5.9
# 11                   Pathaan      Shah Rukh Khan           Action  2023   7.2
#
#     Rank  BoxOffice(INR Crore)
# 0    1.0                  2024
# 1    9.0                   565
# 2    8.0                   201
# 3    6.0                   585
# 4    4.0                   180
# 5    2.0                   111
# 6    7.0                   475
# 7    6.0                   318
# 8    3.0                   342
# 9   11.0                   431
# 10  10.0                   266
# 11   5.0                  1050

# %% [markdown]
# **We can also move a particular column in front**

# %%
cols = ["Actor"] + [col for col in df2.columns if col != "Actor"]
df2 = df2[cols]

# %%
df2
# Out:
#                  Actor                      Film            Genre  Year  IMDb  \
# 0           Aamir Khan                    Dangal        Biography  2016   8.4
# 1          Salman Khan           Tiger Zinda Hai           Action  2017   6.0
# 2         Varun Dhawan     Badrinath Ki Dulhania  Romantic Comedy  2017   6.1
# 3        Ranveer Singh                 Padmaavat       Historical  2018   7.0
# 4        Rajkummar Rao                     Stree    Horror Comedy  2018   7.5
# 5   Ayushmann Khurrana                 Andhadhun         Thriller  2018   8.3
# 6       Hrithik Roshan                       War           Action  2019   6.5
# 7         Akshay Kumar                Good Newwz           Comedy  2019   7.0
# 8        Vicky Kaushal  Uri: The Surgical Strike           Action  2019   8.2
# 9        Ranbir Kapoor                Brahmastra          Fantasy  2022   5.6
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2    Horror Comedy  2022   5.9
# 11      Shah Rukh Khan                   Pathaan           Action  2023   7.2
#
#     Rank  BoxOffice(INR Crore)
# 0    1.0                  2024
# 1    9.0                   565
# 2    8.0                   201
# 3    6.0                   585
# 4    4.0                   180
# 5    2.0                   111
# 6    7.0                   475
# 7    6.0                   318
# 8    3.0                   342
# 9   11.0                   431
# 10  10.0                   266
# 11   5.0                  1050
