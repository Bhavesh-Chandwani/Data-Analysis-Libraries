# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_theme(style="darkgrid")       # Seaborn Theme 
x = np.array([30,45,60,90,180])
y = np.sin(x)
sns.lineplot(x=x, y=y)
plt.title("Beautiful Line Plot.")
plt.show()
