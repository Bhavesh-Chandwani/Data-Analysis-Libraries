# %%
import numpy as np

# %% [markdown]
# **1. np.mean() – Compute the mean (average) of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.mean(arr))
# Out:
# 7.111111111111111

# %% [markdown]
# **2. np.std() – Compute the standard deviation of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.std(arr))
# Out:
# 5.258737584977436

# %% [markdown]
# **3. np.var() – Compute the variance of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.var(arr))
# Out:
# 27.654320987654323

# %% [markdown]
# **4. np.min() – Compute the minimum value of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.min(arr))
# Out:
# 2

# %% [markdown]
# **5. np.max() – Compute the maximum value of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.max(arr))
# Out:
# 20

# %% [markdown]
# **6. np.sum() – Compute the sum of all elements in an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.sum(arr))
# Out:
# 64

# %% [markdown]
# **7. np.prod() – Compute the product of all elements in an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.prod(arr))
# Out:
# 4915200

# %% [markdown]
# **8. np.median() – Compute the median of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.median(arr))
# Out:
# 6.0

# %% [markdown]
# **9. np.percentile() – Compute the percentile of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.percentile(arr, 50))
# Out:
# 6.0

# %% [markdown]
# **10. np.argmin() – Return the index of the minimum value in an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.argmin(arr))
# Out:
# 0

# %% [markdown]
# **11. np.argmax() – Return the index of the maximum value in an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.argmax(arr))
# Out:
# 6

# %% [markdown]
# **12. np.corrcoef() – Compute the correlation coefficient matrix of two arrays.**

# %%
arr1 = np.array([2,4,6,8,2,10,20,4,8])
arr2 = np.array([2,4,7,8,2,10,24,4,9,])
print(np.corrcoef(arr1, arr2))
# Out:
# [[1.        0.9953215]
#  [0.9953215 1.       ]]

# %% [markdown]
# **13. np.unique() – Find the unique elements of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.unique(arr))
# Out:
# [ 2  4  6  8 10 20]

# %% [markdown]
# **14. np.diff() – Compute the n-th differences of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.diff(arr))
# Out:
# [  2   2   2  -6   8  10 -16   4]

# %% [markdown]
# **15. np.cumsum() – Compute the cumulative sum of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.cumsum(arr))
# Out:
# [ 2  6 12 20 22 32 52 56 64]

# %% [markdown]
# **16. np.linspace() – Create an array with evenly spaced numbers over a
# specified interval.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.linspace(0,10, 9))
# Out:
# [ 0.    1.25  2.5   3.75  5.    6.25  7.5   8.75 10.  ]

# %% [markdown]
# **17. np.log() – Compute the natural logarithm of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.log(arr))
# Out:
# [0.69314718 1.38629436 1.79175947 2.07944154 0.69314718 2.30258509
#  2.99573227 1.38629436 2.07944154]

# %% [markdown]
# **18. np.exp() – Compute the exponential of an array.**

# %%
arr = np.array([2,4,6,8,2,10,20,4,8])
print(np.exp(arr))
# Out:
# [7.38905610e+00 5.45981500e+01 4.03428793e+02 2.98095799e+03
#  7.38905610e+00 2.20264658e+04 4.85165195e+08 5.45981500e+01
#  2.98095799e+03]
