# %%
import numpy as np
import time

num = [2,4,6,8,10]
start = time.time()
squared_num = [x ** 2 for x in num]
end = time.time()
print(squared_num)
print(end - start)
# Out:
# [4, 16, 36, 64, 100]
# 0.00030612945556640625

# %%
import numpy as np
import time

num = np.array([2,4,6,8,9])
start = time.time()
squared_num = num**2
end = time.time()
print(squared_num)
print(end - start)
# Out:
# [ 4 16 36 64 81]
# 0.00024247169494628906
